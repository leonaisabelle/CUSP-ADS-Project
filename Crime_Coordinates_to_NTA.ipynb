# %%
# Setting up modules
import geopandas as gpd
import numpy as np
import pandas as pd
from shapely.geometry import Point
import matplotlib.pylab as plt
import geopy

# %%
# Will change this once I find the csv file for 2013-2017 data
crime = pd.read_csv('data/NYPD_Complaint_Data_2018to19.csv')
crime.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   857927015         10.0  MANHATTAN   01/29/2019     16:37:00   01/29/2019
# 1   479254687        101.0     QUEENS   03/29/2019     17:00:00   03/29/2019
# 2   320007604         41.0      BRONX   02/06/2019     02:00:00          NaN
# 3   746022144         68.0   BROOKLYN   01/08/2019     22:49:00   01/08/2019
# 4   145366108         25.0  MANHATTAN   02/11/2019     12:07:00          NaN
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 0     16:45:00        COMPLETED        NaN          NaN
# 1     17:10:00        COMPLETED        NaN          NaN
# 2          NaN        COMPLETED        NaN          NaN
# 3     22:52:00        COMPLETED        NaN          NaN
# 4          NaN        COMPLETED        NaN          NaN
#
#                ...                SUSP_SEX TRANSIT_DISTRICT  VIC_AGE_GROUP  \
# 0              ...                       M              NaN        UNKNOWN
# 1              ...                       M              NaN          25-44
# 2              ...                       M              NaN        UNKNOWN
# 3              ...                       M              NaN        UNKNOWN
# 4              ...                     NaN              NaN        UNKNOWN
#
#   VIC_RACE VIC_SEX X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 0  UNKNOWN       M   984140.0   211709.0  40.747777 -74.000398
# 1    BLACK       F  1054076.0   157437.0  40.598538 -73.748560
# 2  UNKNOWN       D  1011589.0   237996.0  40.819886 -73.901227
# 3  UNKNOWN       E   984439.0   166855.0  40.624663 -73.999321
# 4  UNKNOWN       E  1002776.0   231994.0  40.803435 -73.933084
#
#                          Lat_Lon
# 0  (40.747777093, -74.000398443)
# 1  (40.598537593, -73.748559596)
# 2  (40.819885621, -73.901226998)
# 3  (40.624663129, -73.999320591)
# 4    (40.80343468, -73.93308448)
#
# [5 rows x 35 columns]

# %%
crime.shape
# Out:
# (220998, 35)

# %%
nta = gpd.read_file('data/Neighborhood Tabulation Areas.geojson')
nta.head()
# Out:
#   ntacode     shape_area county_fips         ntaname     shape_leng  \
# 0    BK88  54005018.7472         047    Borough Park  39247.2280737
# 1    QN51   52488276.477         081     Murray Hill   33266.904811
# 2    QN27    19726845.26         081   East Elmhurst  19816.7115378
# 3    QN07  22887772.7683         081          Hollis  20976.3358374
# 4    MN06  10647077.6122         061  Manhattanville  17040.6865482
#
#    boro_name boro_code                                           geometry
# 0   Brooklyn         3  (POLYGON ((-73.97604935657381 40.6312759056467...
# 1     Queens         4  (POLYGON ((-73.80379022888246 40.7756101117924...
# 2     Queens         4  (POLYGON ((-73.86109724401859 40.7636644770877...
# 3     Queens         4  (POLYGON ((-73.75725671509139 40.7181386016625...
# 4  Manhattan         1  (POLYGON ((-73.94607828608069 40.8212632160616...

# %%
# make sure lat long variables are numeric
crime[['Latitude', 'Longitude']].dtypes
# Out:
# Latitude     float64
# Longitude    float64
# dtype: object

# %%
# data cleaning, we wanna remove entries where lat long are null before we do spatial join

# %%
# check out how many rows with lat, long columns each as null
crime[['Latitude', 'Longitude']].isnull().apply(pd.value_counts)
# Out:
#        Latitude  Longitude
# False    220978     220978
# True         20         20

# %%
# the offending 20 rows
crime[crime.Latitude.isnull()]
# Out:
#         CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM  \
# 14338    507845354         41.0      BRONX   01/27/2019     12:42:00
# 21458    325973169         41.0      BRONX   03/27/2018     02:30:00
# 22297    725167396         41.0      BRONX   01/23/2018     12:28:00
# 69074    365998895         40.0      BRONX   12/24/2018     18:30:00
# 70480    672048068         84.0   BROOKLYN   12/20/2018     20:05:00
# 78996    388780984         41.0      BRONX   02/09/2019     16:00:00
# 101246   506222419         41.0      BRONX   04/10/2018     07:30:00
# 103584   436213844        110.0     QUEENS   01/18/2019     01:00:00
# 103790   807134687         84.0   BROOKLYN   03/17/2019     09:51:00
# 114611   268323397          NaN        NaN   06/17/2019     08:37:00
# 116938   359244276         41.0      BRONX   05/20/2019     09:15:00
# 133226   754004317         41.0      BRONX   05/30/2019     10:00:00
# 169874   393021276          NaN        NaN   07/18/2018     19:40:00
# 178443   827141945          NaN        NaN   03/18/2019     05:09:00
# 181337   106062813         41.0      BRONX   03/21/2019     11:15:00
# 193402   140017636          NaN        NaN   06/19/2019     13:10:00
# 194434   894265263         84.0   BROOKLYN   06/15/2019     09:18:00
# 199461   335080914          NaN        NaN   02/09/2019     19:47:00
# 210745   233642762         41.0      BRONX   05/25/2019     03:30:00
# 212802   530756893          5.0  MANHATTAN   05/16/2019     21:09:00
#
#        CMPLNT_TO_DT CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 14338    01/27/2019     12:42:00        COMPLETED        NaN          NaN
# 21458    03/29/2018     12:20:00        COMPLETED        NaN          NaN
# 22297    01/24/2018     12:00:00        COMPLETED        NaN          NaN
# 69074    12/24/2018     18:40:00        COMPLETED        NaN          NaN
# 70480    12/20/2018     20:05:00        COMPLETED        NaN          NaN
# 78996    02/09/2019     17:00:00        COMPLETED        NaN          NaN
# 101246   04/14/2018     12:00:00        COMPLETED        NaN          NaN
# 103584   01/18/2019     06:00:00        COMPLETED        NaN          NaN
# 103790   03/17/2019     09:51:00        COMPLETED        NaN          NaN
# 114611          NaN          NaN        COMPLETED        NaN          NaN
# 116938   05/20/2019     09:15:00        COMPLETED        NaN          NaN
# 133226          NaN          NaN        COMPLETED        NaN          NaN
# 169874          NaN          NaN        COMPLETED        NaN          NaN
# 178443          NaN          NaN        COMPLETED        NaN          NaN
# 181337   03/21/2019     11:15:00        COMPLETED        NaN          NaN
# 193402          NaN          NaN        COMPLETED        NaN          NaN
# 194434   06/15/2019     09:18:00        COMPLETED        NaN          NaN
# 199461          NaN          NaN        COMPLETED        NaN          NaN
# 210745   05/25/2019     03:40:00        COMPLETED        NaN          NaN
# 212802   05/16/2019     21:09:00        COMPLETED        NaN          NaN
#
#              ...         TRANSIT_DISTRICT VIC_AGE_GROUP        VIC_RACE  \
# 14338        ...                      NaN       UNKNOWN         UNKNOWN
# 21458        ...                      NaN         18-24  WHITE HISPANIC
# 22297        ...                      NaN         25-44           BLACK
# 69074        ...                      NaN       UNKNOWN         UNKNOWN
# 70480        ...                      NaN       UNKNOWN         UNKNOWN
# 78996        ...                      NaN         45-64  WHITE HISPANIC
# 101246       ...                      NaN         25-44           BLACK
# 103584       ...                      NaN         45-64           BLACK
# 103790       ...                      NaN       UNKNOWN         UNKNOWN
# 114611       ...                      NaN         45-64  WHITE HISPANIC
# 116938       ...                      NaN       UNKNOWN         UNKNOWN
# 133226       ...                      NaN         25-44  WHITE HISPANIC
# 169874       ...                      NaN       UNKNOWN  WHITE HISPANIC
# 178443       ...                      NaN         25-44  WHITE HISPANIC
# 181337       ...                      NaN       UNKNOWN         UNKNOWN
# 193402       ...                      NaN         25-44           BLACK
# 194434       ...                      NaN       UNKNOWN         UNKNOWN
# 199461       ...                      NaN         45-64  WHITE HISPANIC
# 210745       ...                      NaN         25-44           BLACK
# 212802       ...                      NaN       UNKNOWN         UNKNOWN
#
#        VIC_SEX X_COORD_CD Y_COORD_CD Latitude Longitude  Lat_Lon  \
# 14338        E        NaN        NaN      NaN       NaN      NaN
# 21458        M        NaN        NaN      NaN       NaN      NaN
# 22297        M        NaN        NaN      NaN       NaN      NaN
# 69074        F        NaN        NaN      NaN       NaN      NaN
# 70480        E        NaN        NaN      NaN       NaN      NaN
# 78996        M        NaN        NaN      NaN       NaN      NaN
# 101246       M        NaN        NaN      NaN       NaN      NaN
# 103584       F        NaN        NaN      NaN       NaN      NaN
# 103790       E        NaN        NaN      NaN       NaN      NaN
# 114611       M        NaN        NaN      NaN       NaN      NaN
# 116938       F        NaN        NaN      NaN       NaN      NaN
# 133226       M        NaN        NaN      NaN       NaN      NaN
# 169874       F        NaN        NaN      NaN       NaN      NaN
# 178443       M        NaN        NaN      NaN       NaN      NaN
# 181337       F        NaN        NaN      NaN       NaN      NaN
# 193402       M        NaN        NaN      NaN       NaN      NaN
# 194434       E        NaN        NaN      NaN       NaN      NaN
# 199461       M        NaN        NaN      NaN       NaN      NaN
# 210745       F        NaN        NaN      NaN       NaN      NaN
# 212802       F        NaN        NaN      NaN       NaN      NaN
#
#                geometry
# 14338   POINT (nan nan)
# 21458   POINT (nan nan)
# 22297   POINT (nan nan)
# 69074   POINT (nan nan)
# 70480   POINT (nan nan)
# 78996   POINT (nan nan)
# 101246  POINT (nan nan)
# 103584  POINT (nan nan)
# 103790  POINT (nan nan)
# 114611  POINT (nan nan)
# 116938  POINT (nan nan)
# 133226  POINT (nan nan)
# 169874  POINT (nan nan)
# 178443  POINT (nan nan)
# 181337  POINT (nan nan)
# 193402  POINT (nan nan)
# 194434  POINT (nan nan)
# 199461  POINT (nan nan)
# 210745  POINT (nan nan)
# 212802  POINT (nan nan)
#
# [20 rows x 36 columns]

# %%
# drop the offending rows
crime = crime.dropna(subset=['Latitude', 'Longitude'])
crime.shape # 20 fewer rows
# Out:
# (220978, 36)

# %%
# Create crime geodataframe
crime['geometry'] = crime.apply(lambda crime: Point((crime.Longitude, crime.Latitude)), axis=1)
crime_gdf = gpd.GeoDataFrame(crime, geometry = 'geometry')

# %%
crime_gdf.head(2)
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   857927015         10.0  MANHATTAN   01/29/2019     16:37:00   01/29/2019
# 1   479254687        101.0     QUEENS   03/29/2019     17:00:00   03/29/2019
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  \
# 0     16:45:00        COMPLETED        NaN          NaN
# 1     17:10:00        COMPLETED        NaN          NaN
#
#                        ...                       TRANSIT_DISTRICT  \
# 0                      ...                                    NaN
# 1                      ...                                    NaN
#
#   VIC_AGE_GROUP  VIC_RACE VIC_SEX X_COORD_CD Y_COORD_CD   Latitude  Longitude  \
# 0       UNKNOWN   UNKNOWN       M   984140.0   211709.0  40.747777 -74.000398
# 1         25-44     BLACK       F  1054076.0   157437.0  40.598538 -73.748560
#
#                          Lat_Lon                                      geometry
# 0  (40.747777093, -74.000398443)  POINT (-74.00039844299994 40.74777709300002)
# 1  (40.598537593, -73.748559596)  POINT (-73.74855959599995 40.59853759300007)
#
# [2 rows x 36 columns]

# %%
crime_gdf.crs = nta.crs # ensure they are on the same CRS projection
crime_nta = gpd.sjoin(crime_gdf, nta, op="intersects")

# %%
crime_nta.head(2)
# Out:
#     CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0    857927015         10.0  MANHATTAN   01/29/2019     16:37:00   01/29/2019
# 17   560939215         13.0  MANHATTAN   01/11/2019     02:30:00          NaN
#
#    CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA    ...     \
# 0      16:45:00        COMPLETED        NaN          NaN    ...
# 17          NaN        ATTEMPTED        NaN          NaN    ...
#
#                           Lat_Lon  \
# 0   (40.747777093, -74.000398443)
# 17  (40.739773188, -73.992986319)
#
#                                         geometry  index_right ntacode  \
# 0   POINT (-74.00039844299994 40.74777709300002)          135    MN13
# 17  POINT (-73.99298631899995 40.73977318800007)          135    MN13
#
#        shape_area county_fips                                     ntaname  \
# 0   37068382.0503         061  Hudson Yards-Chelsea-Flatiron-Union Square
# 17  37068382.0503         061  Hudson Yards-Chelsea-Flatiron-Union Square
#
#        shape_leng  boro_name boro_code
# 0   45693.0741371  Manhattan         1
# 17  45693.0741371  Manhattan         1
#
# [2 rows x 44 columns]

# %%
# sanity check for spatial join
(crime_nta.BORO_NM == crime_nta.boro_name.str.upper()).value_counts()

# 705 rows with different boroughs specified?
# Out:
# True     220257
# False       705
# dtype: int64

# %%
error_df = crime_nta[['CMPLNT_FR_DT', 'BORO_NM', 'boro_name']][~(crime_nta.BORO_NM == crime_nta.boro_name.str.upper())]
error_df.head()
# some instances where crime dataset doesn't specify borough
# other instances where crime dataset
# Out:
#        CMPLNT_FR_DT   BORO_NM  boro_name
# 46145    01/31/2019  BROOKLYN     Queens
# 134463   05/19/2019       NaN     Queens
# 116582   06/30/2019       NaN      Bronx
# 7232     03/16/2019       NaN  Manhattan
# 41651    01/19/2019       NaN  Manhattan

# %%
# num of rows where crime dataset's borough is diff from nta dataset's borough
num_diff_boro = len(error_df[~error_df.BORO_NM.isnull()])
print(f"num of rows with different/wrong boroughs={num_diff_boro}")
print(f"that's {num_diff_boro/len(crime_nta)}% of dataset")
# Out:
# num of rows with different/wrong boroughs=576
# that's 0.002606783066771662% of dataset

# %%
# do we want to discard those with diff boroughs?

# %%
# save gdf as csv 
crime_nta.to_csv('data/Crime_NTA.csv')
# crime_nta.to_file("data/crime_NTA.geojson", driver='GeoJSON') # if we wanna save as geojson
