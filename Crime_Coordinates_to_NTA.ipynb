# %%
# Setting up modules
from geopandas import GeoDataFrame
import numpy as np
import pandas as pd
from shapely.geometry import Point
import matplotlib.pylab as plt
import geopy

# %%
#Will change this once I find the csv file for 2013-2017 data
crime = pd.read_csv('data/NYPD_Complaint_Data_2018to19.csv')

# %%
crime.shape
# Out:
# (220998, 35)

# %%
crime.head()
# Out:
#    CMPLNT_NUM  ADDR_PCT_CD    BORO_NM CMPLNT_FR_DT CMPLNT_FR_TM CMPLNT_TO_DT  \
# 0   857927015         10.0  MANHATTAN   01/29/2019     16:37:00   01/29/2019
# 1   479254687        101.0     QUEENS   03/29/2019     17:00:00   03/29/2019
# 2   320007604         41.0      BRONX   02/06/2019     02:00:00          NaN
# 3   746022144         68.0   BROOKLYN   01/08/2019     22:49:00   01/08/2019
# 4   145366108         25.0  MANHATTAN   02/11/2019     12:07:00          NaN
#
#   CMPLNT_TO_TM CRM_ATPT_CPTD_CD HADEVELOPT  HOUSING_PSA  ...  SUSP_SEX  \
# 0     16:45:00        COMPLETED        NaN          NaN  ...         M
# 1     17:10:00        COMPLETED        NaN          NaN  ...         M
# 2          NaN        COMPLETED        NaN          NaN  ...         M
# 3     22:52:00        COMPLETED        NaN          NaN  ...         M
# 4          NaN        COMPLETED        NaN          NaN  ...       NaN
#
#   TRANSIT_DISTRICT  VIC_AGE_GROUP VIC_RACE VIC_SEX X_COORD_CD Y_COORD_CD  \
# ...

# %%
import geopandas as gpd
nta = gpd.read_file('data/Neighborhood Tabulation Areas.geojson')

# %%
nta.head()
# Out:
#   ntacode     shape_area county_fips         ntaname     shape_leng  \
# 0    BK88  54005018.7472         047    Borough Park  39247.2280737
# 1    QN51   52488276.477         081     Murray Hill   33266.904811
# 2    QN27    19726845.26         081   East Elmhurst  19816.7115378
# 3    QN07  22887772.7683         081          Hollis  20976.3358374
# 4    MN06  10647077.6122         061  Manhattanville  17040.6865482
#
#    boro_name boro_code                                           geometry
# 0   Brooklyn         3  (POLYGON ((-73.97604935657381 40.6312759056467...
# 1     Queens         4  (POLYGON ((-73.80379022888246 40.7756101117924...
# 2     Queens         4  (POLYGON ((-73.86109724401859 40.7636644770877...
# 3     Queens         4  (POLYGON ((-73.75725671509139 40.7181386016625...
# 4  Manhattan         1  (POLYGON ((-73.94607828608069 40.8212632160616...

# %%
#Create geometry for crime
crime['Longitude'] = pd.to_numeric(crime['Longitude'])
crime['Latitude'] = pd.to_numeric(crime['Latitude'])

# %%
#Create crime geodataframe
crime['geometry'] = crime.apply(lambda crime: Point((crime.Longitude, crime.Latitude)), axis=1)
gdf = GeoDataFrame(crime, geometry = 'geometry')

# %%
crime_nta = gpd.sjoin(gdf, nta, op="intersects")
# Out:
# /Users/cmvandev/anaconda2/lib/python2.7/site-packages/geopandas/tools/sjoin.py:44: UserWarning: CRS of frames being joined does not match!
#   warn('CRS of frames being joined does not match!')
# ---------------------------------------------------------------------------
# RTreeError                                Traceback (most recent call last)
# <ipython-input-12-d36393d6c2ad> in <module>()
# ----> 1 crime_nta = gpd.sjoin(gdf, nta, op="intersects")
#
# /Users/cmvandev/anaconda2/lib/python2.7/site-packages/geopandas/tools/sjoin.pyc in sjoin(left_df, right_df, how, op, lsuffix, rsuffix)
#      74
#      75     idxmatch = (left_df.geometry.apply(lambda x: x.bounds)
# ---> 76                 .apply(lambda x: list(tree_idx.intersection(x))))
#      77     idxmatch = idxmatch[idxmatch.apply(len) > 0]
#      78
#
# /Users/cmvandev/anaconda2/lib/python2.7/site-packages/pandas/core/series.pyc in apply(self, func, convert_dtype, args, **kwds)
#    3589             else:
# ...

# %%
#Will try this tmr morning: https://stackoverflow.com/questions/34420285/merging-geodataframes-in-geopandas-crs-do-not-match
